# %% [markdown]
# <a href="https://colab.research.google.com/github/midhatkamal5/AssignmentBankingApp/blob/main/BankingApp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from datetime import datetime


def create_account():
    name = input("Enter your name: ")
    account_number = input("Enter your account number: ")
    account = {
        "name": name,
        "account_number": account_number,
        "balance": 0,
        "transaction_history": [],
        "transaction_Count":1
    }
    return account

def deposit(account, amount):
    if amount > 0:
        account["balance"] += amount
        account["transaction_history"].append(f"{account['transaction_Count']}. Credited PKR {amount} on {datetime.now().strftime('%d/%m/%Y %H:%M:%S')}")
        print(f"Dear {account['name']}, PKR {amount} has been credited to your account. Your Current balance is: {account['balance']}.")
        account['transaction_Count'] += 1
    else:
        print("Deposit amount must be positive.")

def withdraw(account, amount):
    if amount > 0:
        if amount <= account["balance"]:
            account["balance"] -= amount
            account["transaction_history"].append(f"{account['transaction_Count']}. Debited  PKR {amount} on {datetime.now().strftime('%d/%m/%Y %H:%M:%S')}")
            print(f"Dear {account['name']}, PKR {amount} has been debited from your account. Your Current balance is: {account['balance']}.")
            account['transaction_Count'] += 1
        else:
            print(f"Dear {account['name']}, you have insufficient funds for this transaction. Please deposit money in order to proceed.")
    else:
        print("Please enter amount greater than 0")

def check_balance(account):
    print(f"Current balance: {account['balance']}")

def view_transactions(account):

    if account["transaction_history"]:
        print(f"Dear {account['name']}, your Transaction History is:")
        for transaction in account["transaction_history"]:
            print(transaction)
    else:
        print("No transactions found")


#-------------------------------------------------------------------------------------
account = None

while True:
    print("*******************************************************************")
    print("************************Welcome to DigiTank************************")
    print("*******************************************************************")
    print("Hello Customer. Here are the desired services which you can avail: ")
    print("1 - Account Opening")
    print("2 - Deposit Money")
    print("3 - Withdraw money")
    print("4 - Check Account Balance")
    print("5 - View Transaction History")
    print("6 - Exit")
    choice = int(input("Please type an option number for your desired service: "))
    print()
    match choice:
      case 1:
        account = create_account()
        print(f"Account created successfully! Welcome {account['name']}.")
        print()

      case 2:
        if account:
          amount = float(input("Enter amount to deposit: "))
          deposit(account, amount)
          print()
        else:
          print("Please create an account first.")
          print()

      case 3:
        if account:
          amount = float(input("Enter amount to withdraw: "))
          withdraw(account, amount)
          print()
        else:
          print("Please create an account first.")
          print()

      case 4:
        if account:
          check_balance(account)
          print()
        else:
          print("Please create an account first.")
          print()
      case 5:
        if account:
          view_transactions(account)
          print()
        else:
          print("Please create an account first.")
          print()
      case 6:
        print("Thank you for choosing Bank DigiTank!")
        break

      case _:
        print("Invalid option chosen. Please choose a valid option to proceed.")
# Out:
# *******************************************************************
# ************************Welcome to DigiTank************************
# *******************************************************************
# Hello Customer. Here are the desired services which you can avail:
# 1 - Account Opening
# 2 - Deposit Money
# 3 - Withdraw money
# 4 - Check Account Balance
# 5 - View Transaction History
# 6 - Exit
# Please type an option number for your desired service: 1
#
# Enter your name: Syeda Midhat Kamal
# Enter your account number: 00059663844523
# Account created successfully! Welcome Syeda Midhat Kamal.
#
# *******************************************************************
# ************************Welcome to DigiTank************************
# *******************************************************************
# Hello Customer. Here are the desired services which you can avail:
# 1 - Account Opening
# 2 - Deposit Money
# 3 - Withdraw money
# 4 - Check Account Balance
# 5 - View Transaction History
# 6 - Exit
# Please type an option number for your desired service: 2
#
# Enter amount to deposit: 1000
# Dear Syeda Midhat Kamal, PKR 1000.0 has been credited to your account. Your Current balance is: 1000.0.
#
# *******************************************************************
# ************************Welcome to DigiTank************************
# *******************************************************************
# Hello Customer. Here are the desired services which you can avail:
# 1 - Account Opening
# 2 - Deposit Money
# 3 - Withdraw money
# 4 - Check Account Balance
# 5 - View Transaction History
# 6 - Exit
# Please type an option number for your desired service: 2
#
# Enter amount to deposit: 7000
# Dear Syeda Midhat Kamal, PKR 7000.0 has been credited to your account. Your Current balance is: 8000.0.
#
# *******************************************************************
# ************************Welcome to DigiTank************************
# *******************************************************************
# Hello Customer. Here are the desired services which you can avail:
# 1 - Account Opening
# 2 - Deposit Money
# 3 - Withdraw money
# 4 - Check Account Balance
# 5 - View Transaction History
# 6 - Exit
# Please type an option number for your desired service: 4
#
# Current balance: 8000.0
#
# *******************************************************************
# ************************Welcome to DigiTank************************
# *******************************************************************
# Hello Customer. Here are the desired services which you can avail:
# 1 - Account Opening
# 2 - Deposit Money
# 3 - Withdraw money
# 4 - Check Account Balance
# 5 - View Transaction History
# 6 - Exit
# Please type an option number for your desired service: 3
#
# Enter amount to withdraw: 9000
# Dear Syeda Midhat Kamal, you have insufficient funds for this transaction. Please deposit money in order to proceed.
#
# *******************************************************************
# ************************Welcome to DigiTank************************
# *******************************************************************
# Hello Customer. Here are the desired services which you can avail:
# 1 - Account Opening
# 2 - Deposit Money
# 3 - Withdraw money
# 4 - Check Account Balance
# 5 - View Transaction History
# 6 - Exit
# Please type an option number for your desired service: 4
#
# Current balance: 8000.0
#
# *******************************************************************
# ************************Welcome to DigiTank************************
# *******************************************************************
# Hello Customer. Here are the desired services which you can avail:
# 1 - Account Opening
# 2 - Deposit Money
# 3 - Withdraw money
# 4 - Check Account Balance
# 5 - View Transaction History
# 6 - Exit
# Please type an option number for your desired service: 500
#
# Invalid option chosen. Please choose a valid option to proceed.
# *******************************************************************
# ************************Welcome to DigiTank************************
# *******************************************************************
# Hello Customer. Here are the desired services which you can avail:
# 1 - Account Opening
# 2 - Deposit Money
# 3 - Withdraw money
# 4 - Check Account Balance
# 5 - View Transaction History
# 6 - Exit
# Please type an option number for your desired service: 3
#
# Enter amount to withdraw: 500
# Dear Syeda Midhat Kamal, PKR 500.0 has been debited from your account. Your Current balance is: 7500.0.
#
# *******************************************************************
# ************************Welcome to DigiTank************************
# *******************************************************************
# Hello Customer. Here are the desired services which you can avail:
# 1 - Account Opening
# 2 - Deposit Money
# 3 - Withdraw money
# 4 - Check Account Balance
# 5 - View Transaction History
# 6 - Exit
# Please type an option number for your desired service: 4
#
# Current balance: 7500.0
#
# *******************************************************************
# ************************Welcome to DigiTank************************
# *******************************************************************
# Hello Customer. Here are the desired services which you can avail:
# 1 - Account Opening
# 2 - Deposit Money
# 3 - Withdraw money
# 4 - Check Account Balance
# 5 - View Transaction History
# 6 - Exit
# Please type an option number for your desired service: 5
#
# Dear Syeda Midhat Kamal, your Transaction History is:
# 1. Credited PKR 1000.0 on 10/12/2024 04:50:58
# 2. Credited PKR 7000.0 on 10/12/2024 04:51:07
# 3. Debited  PKR 500.0 on 10/12/2024 04:51:55
#
# *******************************************************************
# ************************Welcome to DigiTank************************
# *******************************************************************
# Hello Customer. Here are the desired services which you can avail:
# 1 - Account Opening
# 2 - Deposit Money
# 3 - Withdraw money
# 4 - Check Account Balance
# 5 - View Transaction History
# 6 - Exit
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-4fcd426b9ee9> in <cell line: 53>()
#      62     print("5 - View Transaction History")
#      63     print("6 - Exit")
# ---> 64     choice = int(input("Please type an option number for your desired service: "))
#      65     print()
#      66     match choice:
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
#     894                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 895                 raise KeyboardInterrupt("Interrupted by user") from None
#     896             except Exception as e:
#     897                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
